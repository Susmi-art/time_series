# %% [markdown]
# # Case Study - Analyse the data of quarterly shipments transfer of a certain courier company in the $20^{th}$ century.

# %% [markdown]
# #### Basic Libraries import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib
import statsmodels

# %% [markdown]
# ## 1. Read the data in a quarterly Time Series Format.

# %%
df = pd.read_csv('ApplianceShipments.csv')
df.head()
# Out:
#   Quarter  Year  Shipments
# 0      Q1  1985       4009
# 1      Q2  1985       4321
# 2      Q3  1985       4224
# 3      Q4  1985       3944
# 4      Q1  1986       4123

# %%
date = pd.date_range(start='1/1/1985', end='1/1/1990', freq='Q')
date
# Out:
# DatetimeIndex(['1985-03-31', '1985-06-30', '1985-09-30', '1985-12-31',
#                '1986-03-31', '1986-06-30', '1986-09-30', '1986-12-31',
#                '1987-03-31', '1987-06-30', '1987-09-30', '1987-12-31',
#                '1988-03-31', '1988-06-30', '1988-09-30', '1988-12-31',
#                '1989-03-31', '1989-06-30', '1989-09-30', '1989-12-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
df['Time_Stamp'] = date
df.head()
# Out:
#   Quarter  Year  Shipments Time_Stamp
# 0      Q1  1985       4009 1985-03-31
# 1      Q2  1985       4321 1985-06-30
# 2      Q3  1985       4224 1985-09-30
# 3      Q4  1985       3944 1985-12-31
# 4      Q1  1986       4123 1986-03-31

# %%
df.set_index(keys='Time_Stamp',drop=True,inplace=True)
df.head()
# Out:
#            Quarter  Year  Shipments
# Time_Stamp
# 1985-03-31      Q1  1985       4009
# 1985-06-30      Q2  1985       4321
# 1985-09-30      Q3  1985       4224
# 1985-12-31      Q4  1985       3944
# 1986-03-31      Q1  1986       4123

# %%
df.drop(labels=['Quarter','Year'],axis=1,inplace=True)
df.head()
# Out:
#             Shipments
# Time_Stamp
# 1985-03-31       4009
# 1985-06-30       4321
# 1985-09-30       4224
# 1985-12-31       3944
# 1986-03-31       4123

# %% [markdown]
# ## 2. Plot the Time Series data.

# %%
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 15,8

df.plot()
plt.grid();

# %% [markdown]
# ## Find the basic measures of descriptive statistics for this time series across quarters of different years.

# %%
df.describe()
# Out:
#          Shipments
# count    20.000000
# mean   4424.850000
# std     274.089358
# min    3944.000000
# 25%    4239.750000
# 50%    4489.000000
# 75%    4587.500000
# max    4900.000000

# %% [markdown]
# ## 3. Plot the Time series along with the mean and median of the Time series in the graph to get an understanding of the fluctuation of the data from these two measures of central tendency.

# %%
df.plot(color='Red')
plt.axhline(df['Shipments'].mean(),color='Blue')
plt.axhline(df['Shipments'].median(),color='Green')
plt.grid()
plt.legend(['Time Series Plot','Mean','Median']);

# %% [markdown]
# ## 4. Plot a quarterly comparison of the shipments using a barplot.

# %%
sns.barplot(df.index.quarter,df.Shipments,data=df)
plt.grid();
# Out:
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 5. Plot the year on year quarterly comparison of the shipments.

# %%
df.index.month_name
# Out:
# <bound method _inherit_from_data.<locals>.method of DatetimeIndex(['1985-03-31', '1985-06-30', '1985-09-30', '1985-12-31',
#                '1986-03-31', '1986-06-30', '1986-09-30', '1986-12-31',
#                '1987-03-31', '1987-06-30', '1987-09-30', '1987-12-31',
#                '1988-03-31', '1988-06-30', '1988-09-30', '1988-12-31',
#                '1989-03-31', '1989-06-30', '1989-09-30', '1989-12-31'],
#               dtype='datetime64[ns]', name='Time_Stamp', freq=None)>

# %%
quarterly_sales_across_years = pd.pivot_table(df, values = 'Shipments', columns = df.index.month_name(), index = df.index.year)
quarterly_sales_across_years
# Out:
# Time_Stamp  December  June  March  September
# Time_Stamp
# 1985            3944  4321   4009       4224
# 1986            4030  4522   4123       4657
# 1987            4485  4806   4493       4551
# 1988            4258  4799   4595       4417
# 1989            4533  4900   4245       4585

# %%
quarterly_sales_across_years.plot()
plt.grid()

# %% [markdown]
# ## 6. Plot the distribution plot for quarterly comparison of the shipments.

# %%
sns.distplot(df.loc[df.index.quarter == 1]['Shipments'])
sns.distplot(df.loc[df.index.quarter == 2]['Shipments'])
sns.distplot(df.loc[df.index.quarter == 3]['Shipments'])
sns.distplot(df.loc[df.index.quarter == 4]['Shipments'])
plt.grid();
# Out:
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.loc[df.index.quarter == 1]['Shipments'],hist=False)
sns.distplot(df.loc[df.index.quarter == 2]['Shipments'],hist=False)
sns.distplot(df.loc[df.index.quarter == 3]['Shipments'],hist=False)
sns.distplot(df.loc[df.index.quarter == 4]['Shipments'],hist=False)
plt.grid();
# Out:
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUSMITA MANNA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 7. Decompose the data and check the trend, seasonality and the irregular/residual/error component.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(df,model='multiplicative')
decomposition.plot();

# %%
trend = decomposition.trend
seasonality = decomposition.seasonal
residual = decomposition.resid

# %%
print('Trend','\n',trend,'\n')
print('Seasonality','\n',seasonality,'\n')
print('Residual','\n',residual,'\n')
# Out:
# Trend
#  Time_Stamp
# 1985-03-31         NaN
# 1985-06-30         NaN
# 1985-09-30    4138.750
# 1985-12-31    4178.125
# 1986-03-31    4257.375
# 1986-06-30    4322.250
# 1986-09-30    4379.250
# 1986-12-31    4461.000
# 1987-03-31    4483.250
# 1987-06-30    4526.875
# 1987-09-30    4596.500
# 1987-12-31    4608.375
# 1988-03-31    4590.750
# 1988-06-30    4545.625
# 1988-09-30    4473.500
# 1988-12-31    4442.375
# 1989-03-31    4476.000
# 1989-06-30    4531.375
# 1989-09-30         NaN
# 1989-12-31         NaN
# Name: trend, dtype: float64
#
# Seasonality
#  Time_Stamp
# 1985-03-31    0.979648
# 1985-06-30    1.060879
# 1985-09-30    1.015027
# 1985-12-31    0.944446
# 1986-03-31    0.979648
# 1986-06-30    1.060879
# 1986-09-30    1.015027
# 1986-12-31    0.944446
# 1987-03-31    0.979648
# 1987-06-30    1.060879
# 1987-09-30    1.015027
# 1987-12-31    0.944446
# 1988-03-31    0.979648
# 1988-06-30    1.060879
# 1988-09-30    1.015027
# 1988-12-31    0.944446
# 1989-03-31    0.979648
# 1989-06-30    1.060879
# 1989-09-30    1.015027
# 1989-12-31    0.944446
# Name: seasonal, dtype: float64
#
# Residual
#  Time_Stamp
# 1985-03-31         NaN
# 1985-06-30         NaN
# 1985-09-30    1.005489
# 1985-12-31    0.999490
# 1986-03-31    0.988556
# 1986-06-30    0.986177
# 1986-09-30    1.047681
# 1986-12-31    0.956524
# 1987-03-31    1.022995
# 1987-06-30    1.000736
# 1987-09-30    0.975443
# 1987-12-31    1.030475
# 1988-03-31    1.021720
# 1988-06-30    0.995156
# 1988-09-30    0.972753
# 1988-12-31    1.014877
# 1989-03-31    0.968094
# 1989-06-30    1.019296
# 1989-09-30         NaN
# 1989-12-31         NaN
# Name: resid, dtype: float64

# %% [markdown]
# Go ahead and play around with the data to understand the nuances. Try to perform different types of visualizations in order for better understanding of the data.
#
# Happy Learning!

# %% [markdown]
# # END
